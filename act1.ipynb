# %%
import re
with open("../Python2/assets/es-11663-8_UTF8.txt", encoding = 'utf-8') as f:
    lines=f.readlines()

# %% [markdown]
# #Act 2

# %% [markdown]
# #Act1

# %%
# %%time
#se importa libreria para usar regex
import re
#se abre y lee el file
with open("../Python2/assets/es-11663-8_UTF8.txt", encoding = 'utf-8') as f:
    lines=f.readlines()
    
crtrs = {}
comienzo = False

#1.- se iteran las lineas
for renglon in lines:
    #se busca la linea con el asterisco usando regex
    a = re.search('^\*', renglon)   
    #si se encuentra la linea con asteriscos
    if (a != None) and (comienzo == False):
        #imprime
        print(renglon)
        comienzo = True
        #se vuelve a poner como none ya que este nos sirve para encontrar el final
        a = None
        continue
     #si encontramos la ultima linea, imprimimos y salimos con break
    if (a != None) and (comienzo == True):
        print(renglon)
        break
    
    #si ya empezamos checamos cada letra en la linea
    if comienzo == True :                 
        for ltra in renglon:  
            #verifica que char ya esta guardado             
            if ltra not in crtrs:
                #si no esta guardado comenzamos con 1
                crtrs[ltra] = 1
            #si si esta     
            if ltra in crtrs:
                #incrementamos +1
                crtrs[ltra] += 1

for ltra in crtrs: 
    #iteramos y aplicamos un sorted
    sorted(crtrs)        
    #mostramos la letra con su frecuencia                            
    print(f'Letra "{ltra}"  frecuencia -> "{crtrs[ltra]}"')
# Out:
# *** START OF THIS PROJECT GUTENBERG EBOOK EL ARROYO ***
#
# *** END OF THIS PROJECT GUTENBERG EBOOK EL ARROYO ***
#
# Letra "
# "  frecuencia -> "4808"
# Letra "P"  frecuencia -> "149"
# Letra "r"  frecuencia -> "16805"
# Letra "o"  frecuencia -> "20396"
# Letra "d"  frecuencia -> "11975"
# Letra "u"  frecuencia -> "9828"
# Letra "c"  frecuencia -> "8972"
# Letra "e"  frecuencia -> "30461"
# Letra " "  frecuencia -> "45889"
# Letra "b"  frecuencia -> "3409"
# Letra "y"  frecuencia -> "2195"
# Letra "h"  frecuencia -> "1969"
# Letra "t"  frecuencia -> "9548"
# Letra "p"  frecuencia -> "5814"
# Letra ":"  frecuencia -> "87"
# Letra "/"  frecuencia -> "4"
# Letra "g"  frecuencia -> "2848"
# Letra "a"  frecuencia -> "29099"
# Letra "l"  frecuencia -> "14542"
# Letra "i"  frecuencia -> "11966"
# Letra "."  frecuencia -> "1239"
# Letra "n"  frecuencia -> "16248"
# Letra "f"  frecuencia -> "1710"
# Letra ","  frecuencia -> "3927"
# Letra "V"  frecuencia -> "32"
# Letra "q"  frecuencia -> "1934"
# Letra "O"  frecuencia -> "45"
# Letra "D"  frecuencia -> "85"
# Letra "s"  frecuencia -> "20963"
# Letra "T"  frecuencia -> "70"
# Letra "m"  frecuencia -> "6089"
# Letra "E"  frecuencia -> "377"
# Letra "L"  frecuencia -> "229"
# Letra "Í"  frecuencia -> "23"
# Letra "S"  frecuencia -> "109"
# Letra "R"  frecuencia -> "37"
# Letra "C"  frecuencia -> "147"
# Letra "U"  frecuencia -> "56"
# Letra "A"  frecuencia -> "220"
# Letra "Y"  frecuencia -> "38"
# Letra "#"  frecuencia -> "45"
# Letra "í"  frecuencia -> "1197"
# Letra "ó"  frecuencia -> "898"
# Letra "z"  frecuencia -> "997"
# Letra "I"  frecuencia -> "75"
# Letra "M"  frecuencia -> "67"
# Letra "á"  frecuencia -> "1866"
# Letra "ñ"  frecuencia -> "443"
# Letra "v"  frecuencia -> "2393"
# Letra ";"  frecuencia -> "576"
# Letra "é"  frecuencia -> "567"
# Letra "j"  frecuencia -> "975"
# Letra "x"  frecuencia -> "251"
# Letra "ú"  frecuencia -> "198"
# Letra "¿"  frecuencia -> "41"
# Letra "Q"  frecuencia -> "19"
# Letra "?"  frecuencia -> "41"
# Letra "G"  frecuencia -> "22"
# Letra "«"  frecuencia -> "26"
# Letra "»"  frecuencia -> "26"
# Letra "N"  frecuencia -> "84"
# Letra "Ó"  frecuencia -> "2"
# Letra "ü"  frecuencia -> "6"
# Letra "¡"  frecuencia -> "50"
# Letra "!"  frecuencia -> "51"
# Letra "H"  frecuencia -> "36"
# Letra "F"  frecuencia -> "9"
# Letra "_"  frecuencia -> "19"
# Letra "B"  frecuencia -> "20"
# Letra "J"  frecuencia -> "11"
# Letra "k"  frecuencia -> "15"
# Letra "-"  frecuencia -> "54"
# Letra "É"  frecuencia -> "2"
# Letra "Á"  frecuencia -> "2"
# Letra "W"  frecuencia -> "2"
# Letra "X"  frecuencia -> "30"
# Letra """  frecuencia -> "3"
# Letra "1"  frecuencia -> "3"
# Letra "8"  frecuencia -> "2"
# Letra "5"  frecuencia -> "2"
# CPU times: total: 62.5 ms
# Wall time: 45 ms

# %%
# %%time
import re
with open("../Python2/assets/es-11663-8_UTF8.txt", encoding = 'utf-8') as f:
    lines=f.readlines()

crtrs = {}
#se convierte en minusculas
renglon = renglon.lower()
#se quita el \n
renglon = renglon.rstrip()
comienzo = False
                                
 
for renglon in lines:
    a = re.search('^\*', renglon)
    if (a != None) and (comienzo == False):
        print(renglon)
        comienzo = True
        a = None
        continue
     
    if (a != None) and (comienzo == True):
        print(renglon)
        break
    
    #se reemplazan los caracteres
    if comienzo == True :
        renglon = re.sub( '[āēīōū]', 'aeiou', renglon)    
        renglon = re.sub( '[ãõñ]', 'aon', renglon)
        renglon = re.sub( '[àòèìù]', 'aeiou', renglon)
        renglon = re.sub( '[áéíóúý]', 'aeiouy', renglon)
        renglon = re.sub( '[äëïöüÿ]', 'aeiouy', renglon)
        renglon = re.sub( '[âêîôû]', 'aeiou', renglon)   
        
          
        for ltra in renglon:
            if ltra != ' ':
                if ltra not in crtrs:
                    crtrs[ltra] = 1
                if ltra in crtrs:
                    crtrs[ltra] += 1

for ltra in crtrs:    
    sorted(crtrs) 
    print(f'Letra "{ltra}"  frecuencia -> "{crtrs[ltra]}"')
# Out:
# *** START OF THIS PROJECT GUTENBERG EBOOK EL ARROYO ***
#
# *** END OF THIS PROJECT GUTENBERG EBOOK EL ARROYO ***
#
# Letra "
# "  frecuencia -> "4808"
# Letra "P"  frecuencia -> "149"
# Letra "r"  frecuencia -> "16805"
# Letra "o"  frecuencia -> "25564"
# Letra "d"  frecuencia -> "11975"
# Letra "u"  frecuencia -> "14554"
# Letra "c"  frecuencia -> "8972"
# Letra "e"  frecuencia -> "35187"
# Letra "b"  frecuencia -> "3409"
# Letra "y"  frecuencia -> "6921"
# Letra "h"  frecuencia -> "1969"
# Letra "t"  frecuencia -> "9548"
# Letra "p"  frecuencia -> "5814"
# Letra ":"  frecuencia -> "87"
# Letra "/"  frecuencia -> "4"
# Letra "g"  frecuencia -> "2848"
# Letra "a"  frecuencia -> "34267"
# Letra "l"  frecuencia -> "14542"
# Letra "i"  frecuencia -> "16692"
# Letra "."  frecuencia -> "1239"
# Letra "n"  frecuencia -> "16690"
# Letra "f"  frecuencia -> "1710"
# Letra ","  frecuencia -> "3927"
# Letra "V"  frecuencia -> "32"
# Letra "q"  frecuencia -> "1934"
# Letra "O"  frecuencia -> "45"
# Letra "D"  frecuencia -> "85"
# Letra "s"  frecuencia -> "20963"
# Letra "T"  frecuencia -> "70"
# Letra "m"  frecuencia -> "6089"
# Letra "E"  frecuencia -> "377"
# Letra "L"  frecuencia -> "229"
# Letra "Í"  frecuencia -> "23"
# Letra "S"  frecuencia -> "109"
# Letra "R"  frecuencia -> "37"
# Letra "C"  frecuencia -> "147"
# Letra "U"  frecuencia -> "56"
# Letra "A"  frecuencia -> "220"
# Letra "Y"  frecuencia -> "38"
# Letra "#"  frecuencia -> "45"
# Letra "z"  frecuencia -> "997"
# Letra "I"  frecuencia -> "75"
# Letra "M"  frecuencia -> "67"
# Letra "v"  frecuencia -> "2393"
# Letra ";"  frecuencia -> "576"
# Letra "j"  frecuencia -> "975"
# Letra "x"  frecuencia -> "251"
# Letra "¿"  frecuencia -> "41"
# Letra "Q"  frecuencia -> "19"
# Letra "?"  frecuencia -> "41"
# Letra "G"  frecuencia -> "22"
# Letra "«"  frecuencia -> "26"
# Letra "»"  frecuencia -> "26"
# Letra "N"  frecuencia -> "84"
# Letra "Ó"  frecuencia -> "2"
# Letra "¡"  frecuencia -> "50"
# Letra "!"  frecuencia -> "51"
# Letra "H"  frecuencia -> "36"
# Letra "F"  frecuencia -> "9"
# Letra "_"  frecuencia -> "19"
# Letra "B"  frecuencia -> "20"
# Letra "J"  frecuencia -> "11"
# Letra "k"  frecuencia -> "15"
# Letra "-"  frecuencia -> "54"
# Letra "É"  frecuencia -> "2"
# Letra "Á"  frecuencia -> "2"
# Letra "W"  frecuencia -> "2"
# Letra "X"  frecuencia -> "30"
# Letra """  frecuencia -> "3"
# Letra "1"  frecuencia -> "3"
# Letra "8"  frecuencia -> "2"
# Letra "5"  frecuencia -> "2"
# CPU times: total: 78.1 ms
# Wall time: 74.1 ms
