# %% [markdown]
# #Act1

# %%
# %%time
#se importa libreria para usar regex
import re

def counter(lines):
    comienzo = False  
    numero_de_caracteres = 0
    crtrs = {}
    
    #1.- se iteran las linea
    for renglon in lines:   
        #se busca la linea con el asterisco usando regex
        #si se encuentra la linea con asteriscos                   
        if re.search('^\*{3}', renglon) and comienzo == False:     
            print(renglon)                     
            comienzo = True   
            #se vuelve a poner como none ya que este nos sirve para encontrar el final                 
            x = None                        
            continue          
            #si encontramos la ultima linea, imprimimos y salimos con break               
        if re.search('^\*{3}', renglon) and comienzo == False:    
            print(renglon)                     
            break
        #si ya empezamos checamos cada letra en la linea
        if comienzo == True:
            for ltra in renglon:
                #verifica que char ya esta guardado  
                if ltra in crtrs:     
                    #incrementamos +1 
                    crtrs[ltra] += 1   
                    #si no esta guardado comenzamos con 1         
                if ltra not in crtrs:  
                    crtrs[ltra] = 1   

                numero_de_caracteres += 1
                
    #imprimimos el total
    print(f"Total caract -> {numero_de_caracteres}")
    #se retorna la funcion
    return [crtrs, numero_de_caracteres]      

def result(dict):
    crtrs = dict[0]
    numero_de_caracteres = dict[1]
    if numero_de_caracteres == 0:
        numero_de_caracteres = 1
     #frecuencia relativa y normal   
    for ltra in enumerate (crtrs): 
        sorted(crtrs)        
        print(f'Letra -> "{ltra[1]}" Frecuencia del char -> "{crtrs[ltra[1]]}" frecuencia relativa ->  "{crtrs[ltra[1]]*100 /numero_de_caracteres}"')
        
def get(libro):      
    libro = read('en-10012-8_UTF8.txt')

    a = [lines_en]

    for line in a:
        get_dict = counter(line)
        result(get_dict) 
 
print (get(Libro))
# Out:
# *** START OF THIS PROJECT GUTENBERG EBOOK EL ARROYO ***
#
# Total caract -> 315661
# Letra -> "
# " Frecuencia del char -> "5202" frecuencia relativa ->  "1.647970449311128"
# Letra -> "P" Frecuencia del char -> "253" frecuencia relativa ->  "0.08014927406299796"
# Letra -> "r" Frecuencia del char -> "17944" frecuencia relativa ->  "5.684579343029389"
# Letra -> "o" Frecuencia del char -> "21721" frecuencia relativa ->  "6.881116134080548"
# Letra -> "d" Frecuencia del char -> "12497" frecuencia relativa ->  "3.958993984052512"
# Letra -> "u" Frecuencia del char -> "10307" frecuencia relativa ->  "3.2652117303056127"
# Letra -> "c" Frecuencia del char -> "9540" frecuencia relativa ->  "3.02222954371937"
# Letra -> "e" Frecuencia del char -> "32256" frecuencia relativa ->  "10.218557249707755"
# Letra -> " " Frecuencia del char -> "48964" frecuencia relativa ->  "15.511577293362183"
# Letra -> "b" Frecuencia del char -> "3662" frecuencia relativa ->  "1.1601053028407058"
# Letra -> "y" Frecuencia del char -> "2494" frecuencia relativa ->  "0.7900881008423594"
# Letra -> "h" Frecuencia del char -> "2483" frecuencia relativa ->  "0.7866033497961421"
# Letra -> "t" Frecuencia del char -> "11016" frecuencia relativa ->  "3.4898197750118007"
# Letra -> "p" Frecuencia del char -> "6171" frecuencia relativa ->  "1.9549453369279068"
# Letra -> ":" Frecuencia del char -> "111" frecuencia relativa ->  "0.03516430601182915"
# Letra -> "/" Frecuencia del char -> "54" frecuencia relativa ->  "0.017106959681430396"
# Letra -> "g" Frecuencia del char -> "3165" frecuencia relativa ->  "1.0026579146616148"
# Letra -> "a" Frecuencia del char -> "30079" frecuencia relativa ->  "9.528893338106386"
# Letra -> "l" Frecuencia del char -> "15004" frecuencia relativa ->  "4.753200427040401"
# Letra -> "i" Frecuencia del char -> "13023" frecuencia relativa ->  "4.12562844317163"
# Letra -> "." Frecuencia del char -> "1473" frecuencia relativa ->  "0.4666398446434625"
# Letra -> "n" Frecuencia del char -> "17255" frecuencia relativa ->  "5.466307209316324"
# Letra -> "f" Frecuencia del char -> "2056" frecuencia relativa ->  "0.6513316500929794"
# Letra -> "," Frecuencia del char -> "4093" frecuencia relativa ->  "1.2966441847424928"
# Letra -> "V" Frecuencia del char -> "42" frecuencia relativa ->  "0.013305413085556973"
# Letra -> "q" Frecuencia del char -> "1944" frecuencia relativa ->  "0.6158505485314942"
# Letra -> "O" Frecuencia del char -> "104" frecuencia relativa ->  "0.032946737164236316"
# Letra -> "D" Frecuencia del char -> "128" frecuencia relativa ->  "0.04054983035598316"
# Letra -> "s" Frecuencia del char -> "21696" frecuencia relativa ->  "6.8731962453391455"
# Letra -> "T" Frecuencia del char -> "167" frecuencia relativa ->  "0.05290485679257178"
# Letra -> "m" Frecuencia del char -> "6448" frecuencia relativa ->  "2.0426977041826517"
# Letra -> "E" Frecuencia del char -> "495" frecuencia relativa ->  "0.15681379707977863"
# Letra -> "L" Frecuencia del char -> "283" frecuencia relativa ->  "0.08965314055268152"
# Letra -> "Í" Frecuencia del char -> "22" frecuencia relativa ->  "0.006969502092434606"
# Letra -> "S" Frecuencia del char -> "176" frecuencia relativa ->  "0.055756016739476846"
# Letra -> "R" Frecuencia del char -> "104" frecuencia relativa ->  "0.032946737164236316"
# Letra -> "C" Frecuencia del char -> "182" frecuencia relativa ->  "0.05765679003741356"
# Letra -> "U" Frecuencia del char -> "98" frecuencia relativa ->  "0.031045963866299608"
# Letra -> "A" Frecuencia del char -> "292" frecuencia relativa ->  "0.09250430049958658"
# Letra -> "Y" Frecuencia del char -> "65" frecuencia relativa ->  "0.020591710727647698"
# Letra -> "#" Frecuencia del char -> "46" frecuencia relativa ->  "0.014572595284181448"
# Letra -> "í" Frecuencia del char -> "1196" frecuencia relativa ->  "0.37888747738871764"
# Letra -> "ó" Frecuencia del char -> "897" frecuencia relativa ->  "0.28416560804153823"
# Letra -> "z" Frecuencia del char -> "1000" frecuencia relativa ->  "0.31679554965611845"
# Letra -> "I" Frecuencia del char -> "174" frecuencia relativa ->  "0.055122425640164605"
# Letra -> "M" Frecuencia del char -> "88" frecuencia relativa ->  "0.027878008369738423"
# Letra -> "á" Frecuencia del char -> "1865" frecuencia relativa ->  "0.5908237001086609"
# Letra -> "ñ" Frecuencia del char -> "442" frecuencia relativa ->  "0.14002363294800435"
# Letra -> "v" Frecuencia del char -> "2501" frecuencia relativa ->  "0.7923056696899522"
# Letra -> ";" Frecuencia del char -> "575" frecuencia relativa ->  "0.1821574410522681"
# Letra -> "é" Frecuencia del char -> "566" frecuencia relativa ->  "0.17930628110536304"
# Letra -> "j" Frecuencia del char -> "1056" frecuencia relativa ->  "0.33453610043686105"
# Letra -> "x" Frecuencia del char -> "285" frecuencia relativa ->  "0.09028673165199376"
# Letra -> "ú" Frecuencia del char -> "197" frecuencia relativa ->  "0.06240872328225533"
# Letra -> "¿" Frecuencia del char -> "40" frecuencia relativa ->  "0.012671821986244737"
# Letra -> "Q" Frecuencia del char -> "19" frecuencia relativa ->  "0.00601911544346625"
# Letra -> "?" Frecuencia del char -> "40" frecuencia relativa ->  "0.012671821986244737"
# Letra -> "G" Frecuencia del char -> "127" frecuencia relativa ->  "0.04023303480632704"
# Letra -> "«" Frecuencia del char -> "25" frecuencia relativa ->  "0.007919888741402962"
# Letra -> "»" Frecuencia del char -> "25" frecuencia relativa ->  "0.007919888741402962"
# Letra -> "N" Frecuencia del char -> "141" frecuencia relativa ->  "0.0446681725015127"
# Letra -> "Ó" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "ü" Frecuencia del char -> "5" frecuencia relativa ->  "0.001583977748280592"
# Letra -> "¡" Frecuencia del char -> "49" frecuencia relativa ->  "0.015522981933149804"
# Letra -> "!" Frecuencia del char -> "51" frecuencia relativa ->  "0.01615657303246204"
# Letra -> "H" Frecuencia del char -> "60" frecuencia relativa ->  "0.019007732979367104"
# Letra -> "F" Frecuencia del char -> "69" frecuencia relativa ->  "0.02185889292627217"
# Letra -> "_" Frecuencia del char -> "18" frecuencia relativa ->  "0.005702319893810132"
# Letra -> "B" Frecuencia del char -> "60" frecuencia relativa ->  "0.019007732979367104"
# Letra -> "J" Frecuencia del char -> "13" frecuencia relativa ->  "0.0041183421455295395"
# Letra -> "k" Frecuencia del char -> "149" frecuencia relativa ->  "0.047202536898761645"
# Letra -> "-" Frecuencia del char -> "129" frecuencia relativa ->  "0.040866625905639276"
# Letra -> "É" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "Á" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "W" Frecuencia del char -> "16" frecuencia relativa ->  "0.005068728794497895"
# Letra -> "X" Frecuencia del char -> "32" frecuencia relativa ->  "0.01013745758899579"
# Letra -> """ Frecuencia del char -> "24" frecuencia relativa ->  "0.007603093191746842"
# Letra -> "1" Frecuencia del char -> "73" frecuencia relativa ->  "0.023126075124896645"
# Letra -> "8" Frecuencia del char -> "16" frecuencia relativa ->  "0.005068728794497895"
# Letra -> "5" Frecuencia del char -> "15" frecuencia relativa ->  "0.004751933244841776"
# Letra -> "*" Frecuencia del char -> "22" frecuencia relativa ->  "0.006969502092434606"
# Letra -> "K" Frecuencia del char -> "5" frecuencia relativa ->  "0.001583977748280592"
# Letra -> "6" Frecuencia del char -> "20" frecuencia relativa ->  "0.006335910993122368"
# Letra -> "3" Frecuencia del char -> "22" frecuencia relativa ->  "0.006969502092434606"
# Letra -> "w" Frecuencia del char -> "271" frecuencia relativa ->  "0.0858515939568081"
# Letra -> "(" Frecuencia del char -> "23" frecuencia relativa ->  "0.007286297642090724"
# Letra -> ")" Frecuencia del char -> "23" frecuencia relativa ->  "0.007286297642090724"
# Letra -> "2" Frecuencia del char -> "19" frecuencia relativa ->  "0.00601911544346625"
# Letra -> "7" Frecuencia del char -> "7" frecuencia relativa ->  "0.002217568847592829"
# Letra -> "9" Frecuencia del char -> "23" frecuencia relativa ->  "0.007286297642090724"
# Letra -> "4" Frecuencia del char -> "16" frecuencia relativa ->  "0.005068728794497895"
# Letra -> "0" Frecuencia del char -> "41" frecuencia relativa ->  "0.012988617535900856"
# Letra -> "%" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "'" Frecuencia del char -> "8" frecuencia relativa ->  "0.0025343643972489476"
# Letra -> "@" Frecuencia del char -> "2" frecuencia relativa ->  "0.0006335910993122369"
# Letra -> "$" Frecuencia del char -> "2" frecuencia relativa ->  "0.0006335910993122369"
# None
# CPU times: total: 46.9 ms
# Wall time: 45 ms

# %% [markdown]
# #Act 2

# %%
# %%time
#se importa libreria para usar regex
import re

def counter(lines):
    comienzo = False  
    numero_de_caracteres = 0
    crtrs = {}
    
    #1.- se iteran las linea
    for renglon in lines:   
        #se busca la linea con el asterisco usando regex
        #si se encuentra la linea con asteriscos                   
        if re.search('^\*{3}', renglon) and comienzo == False:     
            print(renglon)                     
            comienzo = True   
            #se vuelve a poner como none ya que este nos sirve para encontrar el final                 
            x = None                        
            continue          
            #si encontramos la ultima linea, imprimimos y salimos con break               
        if re.search('^\*{3}', renglon) and comienzo == False:    
            print(renglon)                     
            break
        #si ya empezamos checamos cada letra en la linea
        if comienzo == True:
            for ltra in renglon:
                #verifica que char ya esta guardado  
                if ltra in crtrs:     
                    #incrementamos +1 
                    crtrs[ltra] += 1   
                    #si no esta guardado comenzamos con 1         
                if ltra not in crtrs:  
                    crtrs[ltra] = 1   

                numero_de_caracteres += 1
                
    #imprimimos el total
    print(f"Total caract -> {numero_de_caracteres}")
    #se retorna la funcion
    return [crtrs, numero_de_caracteres] 
 
def limpiar_caracteres(lines):
    renglon = re.sub( '[äëïöüÿ]', 'aeiouy', renglon)
    renglon = re.sub( '[âááäāãàå]', 'a', renglon)   
    renglon = re.sub( '[èêééëē]', 'e', renglon)
    renglon = re.sub( '[ÿý]', 'y', renglon)
    renglon = re.sub( '[ôóöōõòø]', 'o', renglon)
    renglon = re.sub( '[ûúüūù]', 'u', renglon)    
    renglon = re.sub( '[ç]', 's', renglon)
    renglon = re.sub( '[æ]', 'ae', renglon)
    renglon = re.sub( '[ß]', 'ss', renglon)
    renglon = renglon.rstrip()
    renglon = renglon.lower() 
    return line    

def get(libro):      
    libro = read('en-10012-8_UTF8.txt')

    a = [lines_en]

    for line in a:
        get_dict = counter(line)
        result(get_dict) 
 
print (get(Libro))
# Out:
# *** START OF THIS PROJECT GUTENBERG EBOOK EL ARROYO ***
#
# Total caract -> 315661
# Letra -> "
# " Frecuencia del char -> "5202" frecuencia relativa ->  "1.647970449311128"
# Letra -> "P" Frecuencia del char -> "253" frecuencia relativa ->  "0.08014927406299796"
# Letra -> "r" Frecuencia del char -> "17944" frecuencia relativa ->  "5.684579343029389"
# Letra -> "o" Frecuencia del char -> "21721" frecuencia relativa ->  "6.881116134080548"
# Letra -> "d" Frecuencia del char -> "12497" frecuencia relativa ->  "3.958993984052512"
# Letra -> "u" Frecuencia del char -> "10307" frecuencia relativa ->  "3.2652117303056127"
# Letra -> "c" Frecuencia del char -> "9540" frecuencia relativa ->  "3.02222954371937"
# Letra -> "e" Frecuencia del char -> "32256" frecuencia relativa ->  "10.218557249707755"
# Letra -> " " Frecuencia del char -> "48964" frecuencia relativa ->  "15.511577293362183"
# Letra -> "b" Frecuencia del char -> "3662" frecuencia relativa ->  "1.1601053028407058"
# Letra -> "y" Frecuencia del char -> "2494" frecuencia relativa ->  "0.7900881008423594"
# Letra -> "h" Frecuencia del char -> "2483" frecuencia relativa ->  "0.7866033497961421"
# Letra -> "t" Frecuencia del char -> "11016" frecuencia relativa ->  "3.4898197750118007"
# Letra -> "p" Frecuencia del char -> "6171" frecuencia relativa ->  "1.9549453369279068"
# Letra -> ":" Frecuencia del char -> "111" frecuencia relativa ->  "0.03516430601182915"
# Letra -> "/" Frecuencia del char -> "54" frecuencia relativa ->  "0.017106959681430396"
# Letra -> "g" Frecuencia del char -> "3165" frecuencia relativa ->  "1.0026579146616148"
# Letra -> "a" Frecuencia del char -> "30079" frecuencia relativa ->  "9.528893338106386"
# Letra -> "l" Frecuencia del char -> "15004" frecuencia relativa ->  "4.753200427040401"
# Letra -> "i" Frecuencia del char -> "13023" frecuencia relativa ->  "4.12562844317163"
# Letra -> "." Frecuencia del char -> "1473" frecuencia relativa ->  "0.4666398446434625"
# Letra -> "n" Frecuencia del char -> "17255" frecuencia relativa ->  "5.466307209316324"
# Letra -> "f" Frecuencia del char -> "2056" frecuencia relativa ->  "0.6513316500929794"
# Letra -> "," Frecuencia del char -> "4093" frecuencia relativa ->  "1.2966441847424928"
# Letra -> "V" Frecuencia del char -> "42" frecuencia relativa ->  "0.013305413085556973"
# Letra -> "q" Frecuencia del char -> "1944" frecuencia relativa ->  "0.6158505485314942"
# Letra -> "O" Frecuencia del char -> "104" frecuencia relativa ->  "0.032946737164236316"
# Letra -> "D" Frecuencia del char -> "128" frecuencia relativa ->  "0.04054983035598316"
# Letra -> "s" Frecuencia del char -> "21696" frecuencia relativa ->  "6.8731962453391455"
# Letra -> "T" Frecuencia del char -> "167" frecuencia relativa ->  "0.05290485679257178"
# Letra -> "m" Frecuencia del char -> "6448" frecuencia relativa ->  "2.0426977041826517"
# Letra -> "E" Frecuencia del char -> "495" frecuencia relativa ->  "0.15681379707977863"
# Letra -> "L" Frecuencia del char -> "283" frecuencia relativa ->  "0.08965314055268152"
# Letra -> "Í" Frecuencia del char -> "22" frecuencia relativa ->  "0.006969502092434606"
# Letra -> "S" Frecuencia del char -> "176" frecuencia relativa ->  "0.055756016739476846"
# Letra -> "R" Frecuencia del char -> "104" frecuencia relativa ->  "0.032946737164236316"
# Letra -> "C" Frecuencia del char -> "182" frecuencia relativa ->  "0.05765679003741356"
# Letra -> "U" Frecuencia del char -> "98" frecuencia relativa ->  "0.031045963866299608"
# Letra -> "A" Frecuencia del char -> "292" frecuencia relativa ->  "0.09250430049958658"
# Letra -> "Y" Frecuencia del char -> "65" frecuencia relativa ->  "0.020591710727647698"
# Letra -> "#" Frecuencia del char -> "46" frecuencia relativa ->  "0.014572595284181448"
# Letra -> "í" Frecuencia del char -> "1196" frecuencia relativa ->  "0.37888747738871764"
# Letra -> "ó" Frecuencia del char -> "897" frecuencia relativa ->  "0.28416560804153823"
# Letra -> "z" Frecuencia del char -> "1000" frecuencia relativa ->  "0.31679554965611845"
# Letra -> "I" Frecuencia del char -> "174" frecuencia relativa ->  "0.055122425640164605"
# Letra -> "M" Frecuencia del char -> "88" frecuencia relativa ->  "0.027878008369738423"
# Letra -> "á" Frecuencia del char -> "1865" frecuencia relativa ->  "0.5908237001086609"
# Letra -> "ñ" Frecuencia del char -> "442" frecuencia relativa ->  "0.14002363294800435"
# Letra -> "v" Frecuencia del char -> "2501" frecuencia relativa ->  "0.7923056696899522"
# Letra -> ";" Frecuencia del char -> "575" frecuencia relativa ->  "0.1821574410522681"
# Letra -> "é" Frecuencia del char -> "566" frecuencia relativa ->  "0.17930628110536304"
# Letra -> "j" Frecuencia del char -> "1056" frecuencia relativa ->  "0.33453610043686105"
# Letra -> "x" Frecuencia del char -> "285" frecuencia relativa ->  "0.09028673165199376"
# Letra -> "ú" Frecuencia del char -> "197" frecuencia relativa ->  "0.06240872328225533"
# Letra -> "¿" Frecuencia del char -> "40" frecuencia relativa ->  "0.012671821986244737"
# Letra -> "Q" Frecuencia del char -> "19" frecuencia relativa ->  "0.00601911544346625"
# Letra -> "?" Frecuencia del char -> "40" frecuencia relativa ->  "0.012671821986244737"
# Letra -> "G" Frecuencia del char -> "127" frecuencia relativa ->  "0.04023303480632704"
# Letra -> "«" Frecuencia del char -> "25" frecuencia relativa ->  "0.007919888741402962"
# Letra -> "»" Frecuencia del char -> "25" frecuencia relativa ->  "0.007919888741402962"
# Letra -> "N" Frecuencia del char -> "141" frecuencia relativa ->  "0.0446681725015127"
# Letra -> "Ó" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "ü" Frecuencia del char -> "5" frecuencia relativa ->  "0.001583977748280592"
# Letra -> "¡" Frecuencia del char -> "49" frecuencia relativa ->  "0.015522981933149804"
# Letra -> "!" Frecuencia del char -> "51" frecuencia relativa ->  "0.01615657303246204"
# Letra -> "H" Frecuencia del char -> "60" frecuencia relativa ->  "0.019007732979367104"
# Letra -> "F" Frecuencia del char -> "69" frecuencia relativa ->  "0.02185889292627217"
# Letra -> "_" Frecuencia del char -> "18" frecuencia relativa ->  "0.005702319893810132"
# Letra -> "B" Frecuencia del char -> "60" frecuencia relativa ->  "0.019007732979367104"
# Letra -> "J" Frecuencia del char -> "13" frecuencia relativa ->  "0.0041183421455295395"
# Letra -> "k" Frecuencia del char -> "149" frecuencia relativa ->  "0.047202536898761645"
# Letra -> "-" Frecuencia del char -> "129" frecuencia relativa ->  "0.040866625905639276"
# Letra -> "É" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "Á" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "W" Frecuencia del char -> "16" frecuencia relativa ->  "0.005068728794497895"
# Letra -> "X" Frecuencia del char -> "32" frecuencia relativa ->  "0.01013745758899579"
# Letra -> """ Frecuencia del char -> "24" frecuencia relativa ->  "0.007603093191746842"
# Letra -> "1" Frecuencia del char -> "73" frecuencia relativa ->  "0.023126075124896645"
# Letra -> "8" Frecuencia del char -> "16" frecuencia relativa ->  "0.005068728794497895"
# Letra -> "5" Frecuencia del char -> "15" frecuencia relativa ->  "0.004751933244841776"
# Letra -> "*" Frecuencia del char -> "22" frecuencia relativa ->  "0.006969502092434606"
# Letra -> "K" Frecuencia del char -> "5" frecuencia relativa ->  "0.001583977748280592"
# Letra -> "6" Frecuencia del char -> "20" frecuencia relativa ->  "0.006335910993122368"
# Letra -> "3" Frecuencia del char -> "22" frecuencia relativa ->  "0.006969502092434606"
# Letra -> "w" Frecuencia del char -> "271" frecuencia relativa ->  "0.0858515939568081"
# Letra -> "(" Frecuencia del char -> "23" frecuencia relativa ->  "0.007286297642090724"
# Letra -> ")" Frecuencia del char -> "23" frecuencia relativa ->  "0.007286297642090724"
# Letra -> "2" Frecuencia del char -> "19" frecuencia relativa ->  "0.00601911544346625"
# Letra -> "7" Frecuencia del char -> "7" frecuencia relativa ->  "0.002217568847592829"
# Letra -> "9" Frecuencia del char -> "23" frecuencia relativa ->  "0.007286297642090724"
# Letra -> "4" Frecuencia del char -> "16" frecuencia relativa ->  "0.005068728794497895"
# Letra -> "0" Frecuencia del char -> "41" frecuencia relativa ->  "0.012988617535900856"
# Letra -> "%" Frecuencia del char -> "1" frecuencia relativa ->  "0.00031679554965611845"
# Letra -> "'" Frecuencia del char -> "8" frecuencia relativa ->  "0.0025343643972489476"
# Letra -> "@" Frecuencia del char -> "2" frecuencia relativa ->  "0.0006335910993122369"
# Letra -> "$" Frecuencia del char -> "2" frecuencia relativa ->  "0.0006335910993122369"
# None
# CPU times: total: 46.9 ms
# Wall time: 47 ms
